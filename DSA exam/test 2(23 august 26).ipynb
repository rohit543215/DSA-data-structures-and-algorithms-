# %% [markdown]
# Question 1
#
# Move Zeroes
#
# Given an integer array nums, move all 0's to the end of it while maintaining the relative order of the non-zero elements. You must do this in-place without making a copy of the array.
#
# Input: nums = [0,1,0,3,12]
# Output: [1,3,12,0,0]
#
# Constraints: 1 <= nums.length <= 10^4, -2^31 <= nums[i] <= 2^31 - 1
#
# Follow-up: minimize the total number of operations.

# %%
def moveZeroes(nums):
    start_pos=0
    for i in range(len(nums)):
      if nums[i]!=0:
        nums[start_pos]=nums[i]
        start_pos+=1
    for i in range(start_pos,len(nums)):
      nums[i]=0    
        
nums=[0,1,0,2,12]
moveZeroes(nums)
print(nums)
# Out:
# [1, 2, 12, 0, 0]

# %% [markdown]
# Question 2
#
# Single Number
#
# Given a non-empty array of integers nums, every element appears twice except for one. Find that single one.
#
# Input: nums = [4,1,2,1,2]
# Output: 4
#
# Constraints: 1 <= nums.length <= 3*10^4, -3*10^4 <= nums[i] <= 3*10^4
#
# Follow-up: your algorithm should have linear runtime complexity. Can you implement it without using extra memory?

# %%
def singleNumber(nums):
    result=0
    for i in nums:
        result^=i
    return result
nums=[4,1,2,1,2]
singleNumber(nums)
# Out:
# 4

# %% [markdown]
# Question 3
#
# Plus One
#
# You are given a large integer represented as an integer array digits, where each digits[i] is the ith digit of the integer, ordered from most significant to least significant (no leading zeros). Increment the large integer by one and return the resulting array of digits.
#
# Input: digits = [1,2,3]
# Output: [1,2,4]
# Input: digits = [9,9]
# Output: [1,0,0]
#
# Constraints: 1 <= digits.length <= 100, 0 <= digits[i] <= 9

# %%
def plusOne(nums):
  n=len(nums)
  for i in range(n-1,-1,-1):
      if nums[i]<9:
        nums[i]=nums[i]+1
        return nums
      else: 
        nums[i]=0
  return [1]+nums
nums=[1,2,9]
plusOne(nums)
# Out:
# [1, 3, 0]

# %% [markdown]
# Question 4
#
# Remove Element
#
# Given an integer array nums and an integer val, remove all occurrences of val in nums in-place. The order of the remaining elements may be changed. Return k, the number of elements not equal to val — the first k elements of nums should hold the final result.
#
# Input: nums = [3,2,2,3], val = 3
# Output: 2, nums = [2,2,_,_]
#
# Constraints: 0 <= nums.length <= 100, 0 <= nums[i] <= 50, 0 <= val <= 100

# %%
def removeElement(nums,val):
   slow=0
   for i in range(len(nums)):
    if nums[i]!=val:
        nums[slow]=nums[i]
        slow+=1
   return slow  
nums=[3,2,2,3]
removeElement(nums,3)
# Out:
# 2

# %% [markdown]
# Question 5
#
# Majority Element
#
# Given an array nums of size n, return the majority element — the element that appears more than ⌊n / 2⌋ times. You may assume the majority element always exists in the array.
#
# Input: nums = [2,2,1,1,1,2,2]
# Output: 2
#
# Constraints: n == nums.length, 1 <= n <= 5*10^4, -10^9 <= nums[i] <= 10^9
#
# Follow-up: could you solve it in O(n) time and O(1) space?

# %%
class Solution(object):
    def majorityElement(self, nums):
        freq={}
        for i in nums:
            freq[i]=freq.get(i,0)+1
        for key,value in freq.items():
            if value>len(nums)//2:
                return key   
soln=Solution()
majority=soln.majorityElement([3,2,3])   
print(majority)
# Out:
# 3

# %% [markdown]
# Question 6
#
# Merge Sorted Array
#
# You are given two integer arrays nums1 and nums2, sorted in non-decreasing order, and two integers m and n, representing the number of elements in nums1 and nums2 respectively. nums1 has a length of m + n, where the first m elements represent the actual elements, and the last n elements are set to 0 and should be ignored. Merge nums2 into nums1 as one sorted array, in-place.
#
# Input: nums1 = [1,2,3,0,0,0], m = 3, nums2 = [2,5,6], n = 3
# Output: [1,2,2,3,5,6]
#
# Constraints: nums1.length == m + n, nums2.length == n, 0 <= m, n <= 200, 1 <= m + n <= 200

# %%
def mergeSort(nums1,m,nums2,n):
  p1=m-1
  p2=n-1
  p_write=m+n-1
  while p1>=0 and p2>=0:
    if nums1[p1]>nums2[p2]:
      nums1[p_write]=nums1[p1]
      p1-=1
    else:
      nums1[p_write]=nums2[p2]
      p2-=1
    p_write-=1
  while p2>=0:   
    nums1[p_write]=nums2[p2]
    p2-=1
    p_write-=1
  return nums1
nums1 = [1,2,3,0,0,0]
m = 3
nums2 = [2,5,6]
n = 3       
mergeSort(nums1,m,nums2,n)
# Out:
# [1, 2, 2, 3, 5, 6]
